# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %% [markdown]
# # READ DATA FILE

# %%
data = pd.read_excel(r"Downloads\Customer Raw data.xlsx")  
data
# Out:
# C:\Users\admin\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py:312: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)
#            PID                                   Product Name Category  \
# 0    CL0036386            Ikat stripe print cotton knit dress    Dress
# 1    CL0030567                    Feminine pleated knit dress    Dress
# 2    CL0032320   Floral embellished chambray denim maxi dress    Dress
# 3    CL0036700                     Dot print cap sleeve shirt      Top
# 4    CL0036365          Layered asymmetric hem hacci knit top      Top
# ..         ...                                            ...      ...
# 711  CL0031288                      Ruffle front poplin dress    Dress
# 712  CL0032199              Beaded cotton poplin sheath dress    Dress
# 713  CL0031267          Embellished stripe waist poplin dress    Dress
# 714  CL0031287                        Sash waist poplin skirt    Skirt
# 715  CL0031947                  Colorblock retro poplin frock    Dress
#
#      Final Price  Initial Price                Color        Primary Color  \
# 0          84.95          33.95      Blue/navy/white                 Blue
# 1          59.95          41.95            Navy blue            Navy blue
# 2          96.95          67.95          Deep indigo          Deep indigo
# 3          49.95          19.95           White/navy                White
# 4          69.95          27.95                 Blue                 Blue
# ..           ...            ...                  ...                  ...
# 711        69.95          52.95         Spring green         Spring green
# 712        86.95          65.95         Spring green         Spring green
# 713        76.95          57.95   Spring green multi   Spring green multi
# 714        59.95          44.95         Spring green         Spring green
# 715        59.95          44.95   Black/spring green                Black
#
#               Fabric
# 0     Cotton Spandex
# 1     Cotton Spandex
# 2             Cotton
# 3             Cotton
# 4          Polyester
# ..               ...
# 711           Cotton
# 712           Cotton
# 713           Cotton
# 714           Cotton
# 715           Cotton
#
# [716 rows x 8 columns]

# %%
data.head()
# Out:
#          PID                                   Product Name Category  \
# 0  CL0036386            Ikat stripe print cotton knit dress    Dress
# 1  CL0030567                    Feminine pleated knit dress    Dress
# 2  CL0032320   Floral embellished chambray denim maxi dress    Dress
# 3  CL0036700                     Dot print cap sleeve shirt      Top
# 4  CL0036365          Layered asymmetric hem hacci knit top      Top
#
#    Final Price  Initial Price             Color Primary Color           Fabric
# 0        84.95          33.95   Blue/navy/white          Blue   Cotton Spandex
# 1        59.95          41.95         Navy blue     Navy blue   Cotton Spandex
# 2        96.95          67.95       Deep indigo   Deep indigo           Cotton
# 3        49.95          19.95        White/navy         White           Cotton
# 4        69.95          27.95              Blue          Blue        Polyester

# %% [markdown]
# # WRITE DATA INTO FILE

# %%
data.to_excel("Customer Raw data.xlsx", index= False)

# %% [markdown]
# # PRINT DATA

# %%
data.head()
# Out:
#          PID                                   Product Name Category  \
# 0  CL0036386            Ikat stripe print cotton knit dress    Dress
# 1  CL0030567                    Feminine pleated knit dress    Dress
# 2  CL0032320   Floral embellished chambray denim maxi dress    Dress
# 3  CL0036700                     Dot print cap sleeve shirt      Top
# 4  CL0036365          Layered asymmetric hem hacci knit top      Top
#
#    Final Price  Initial Price             Color Primary Color           Fabric
# 0        84.95          33.95   Blue/navy/white          Blue   Cotton Spandex
# 1        59.95          41.95         Navy blue     Navy blue   Cotton Spandex
# 2        96.95          67.95       Deep indigo   Deep indigo           Cotton
# 3        49.95          19.95        White/navy         White           Cotton
# 4        69.95          27.95              Blue          Blue        Polyester

# %%
data.tail()
# Out:
#            PID                            Product Name Category  Final Price  \
# 711  CL0031288               Ruffle front poplin dress    Dress        69.95
# 712  CL0032199       Beaded cotton poplin sheath dress    Dress        86.95
# 713  CL0031267   Embellished stripe waist poplin dress    Dress        76.95
# 714  CL0031287                 Sash waist poplin skirt    Skirt        59.95
# 715  CL0031947           Colorblock retro poplin frock    Dress        59.95
#
#      Initial Price                Color        Primary Color   Fabric
# 711          52.95         Spring green         Spring green   Cotton
# 712          65.95         Spring green         Spring green   Cotton
# 713          57.95   Spring green multi   Spring green multi   Cotton
# 714          44.95         Spring green         Spring green   Cotton
# 715          44.95   Black/spring green                Black   Cotton

# %%
data.columns
# Out:
# Index(['PID', 'Product Name', 'Category', 'Final Price', 'Initial Price',
#        'Color', 'Primary Color', 'Fabric'],
#       dtype='object')

# %%
data.shape
# Out:
# (716, 8)

# %% [markdown]
# # SUMMARIZE DATA

# %%
data.describe()
# Out:
#        Final Price  Initial Price
# count   716.000000     716.000000
# mean     87.556145      59.961173
# std      65.990685      68.248824
# min      39.950000      19.950000
# 25%      61.950000      39.700000
# 50%      79.950000      47.950000
# 75%      96.950000      59.950000
# max     699.950000     699.950000

# %%
data.describe(include='all')
# Out:
#               PID                           Product Name Category  \
# count         716                                    716      716
# unique        716                                    646        6
# top     CL0033370   Chevron stripe colorblock maxi dress    Dress
# freq            1                                      7      428
# mean          NaN                                    NaN      NaN
# std           NaN                                    NaN      NaN
# min           NaN                                    NaN      NaN
# 25%           NaN                                    NaN      NaN
# 50%           NaN                                    NaN      NaN
# 75%           NaN                                    NaN      NaN
# max           NaN                                    NaN      NaN
#
#         Final Price  Initial Price   Color Primary Color   Fabric
# count    716.000000     716.000000     716           716      716
# unique          NaN            NaN     327           122       26
# top             NaN            NaN   Black         Black   Cotton
# freq            NaN            NaN      39           100      263
# mean      87.556145      59.961173     NaN           NaN      NaN
# std       65.990685      68.248824     NaN           NaN      NaN
# min       39.950000      19.950000     NaN           NaN      NaN
# 25%       61.950000      39.700000     NaN           NaN      NaN
# 50%       79.950000      47.950000     NaN           NaN      NaN
# 75%       96.950000      59.950000     NaN           NaN      NaN
# max      699.950000     699.950000     NaN           NaN      NaN

# %% [markdown]
# # DATA INFORMATION

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 716 entries, 0 to 715
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   PID            716 non-null    object
#  1   Product Name   716 non-null    object
#  2   Category       716 non-null    object
#  3   Final Price    716 non-null    float64
#  4   Initial Price  716 non-null    float64
#  5   Color          716 non-null    object
#  6   Primary Color  716 non-null    object
#  7   Fabric         716 non-null    object
# dtypes: float64(2), object(6)
# memory usage: 44.9+ KB

# %% [markdown]
# # FINDING NULL VALUES

# %%
data.isnull()
# Out:
#        PID  Product Name  Category  Final Price  Initial Price  Color  \
# 0    False         False     False        False          False  False
# 1    False         False     False        False          False  False
# 2    False         False     False        False          False  False
# 3    False         False     False        False          False  False
# 4    False         False     False        False          False  False
# ..     ...           ...       ...          ...            ...    ...
# 711  False         False     False        False          False  False
# 712  False         False     False        False          False  False
# 713  False         False     False        False          False  False
# 714  False         False     False        False          False  False
# 715  False         False     False        False          False  False
#
#      Primary Color  Fabric
# 0            False   False
# 1            False   False
# 2            False   False
# 3            False   False
# 4            False   False
# ..             ...     ...
# 711          False   False
# 712          False   False
# 713          False   False
# 714          False   False
# 715          False   False
#
# [716 rows x 8 columns]

# %%
data.isnull().sum()
# Out:
# PID              0
# Product Name     0
# Category         0
# Final Price      0
# Initial Price    0
# Color            0
# Primary Color    0
# Fabric           0
# dtype: int64
